# %% [markdown]
# # ML2025 Homework 1 - Retrieval Augmented Generation with Agents

# %% [markdown]
# ## Environment Setup

# %% [markdown]
# In this section, we install the necessary python packages and download model weights of the quantized version of LLaMA 3.1 8B. Also, download the dataset. Note that the model weight is around 8GB.

# %%
# !python3 -m pip install --no-cache-dir llama-cpp-python==0.3.4 --extra-index-url https://abetlen.github.io/llama-cpp-python/whl/cu122
# !python3 -m pip install googlesearch-python bs4 charset-normalizer requests-html lxml_html_clean

from pathlib import Path
if not Path('./Meta-Llama-3.1-8B-Instruct-Q8_0.gguf').exists():
    # !wget https://huggingface.co/bartowski/Meta-Llama-3.1-8B-Instruct-GGUF/resolve/main/Meta-Llama-3.1-8B-Instruct-Q8_0.gguf
if not Path('./public.txt').exists():
    # !wget https://www.csie.ntu.edu.tw/~ulin/public.txt
if not Path('./private.txt').exists():
    # !wget https://www.csie.ntu.edu.tw/~ulin/private.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://abetlen.github.io/llama-cpp-python/whl/cu122
# Requirement already satisfied: llama-cpp-python==0.3.4 in /usr/local/lib/python3.10/dist-packages (0.3.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-cpp-python==0.3.4) (4.12.2)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from llama-cpp-python==0.3.4) (1.26.4)
# Requirement already satisfied: diskcache>=5.6.1 in /usr/local/lib/python3.10/dist-packages (from llama-cpp-python==0.3.4) (5.6.3)
# Requirement already satisfied: jinja2>=2.11.3 in /usr/local/lib/python3.10/dist-packages (from llama-cpp-python==0.3.4) (3.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.11.3->llama-cpp-python==0.3.4) (3.0.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20.0->llama-cpp-python==0.3.4) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20.0->llama-cpp-python==0.3.4) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20.0->llama-cpp-python==0.3.4) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20.0->llama-cpp-python==0.3.4) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20.0->llama-cpp-python==0.3.4) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20.0->llama-cpp-python==0.3.4) (2.4.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.20.0->llama-cpp-python==0.3.4) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.20.0->llama-cpp-python==0.3.4) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.20.0->llama-cpp-python==0.3.4) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.20.0->llama-cpp-python==0.3.4) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.20.0->llama-cpp-python==0.3.4) (2024.2.0)
# Requirement already satisfied: googlesearch-python in /usr/local/lib/python3.10/dist-packages (1.3.0)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.10/dist-packages (0.0.2)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: requests-html in /usr/local/lib/python3.10/dist-packages (0.10.0)
# Requirement already satisfied: lxml_html_clean in /usr/local/lib/python3.10/dist-packages (0.4.1)
# Requirement already satisfied: beautifulsoup4>=4.9 in /usr/local/lib/python3.10/dist-packages (from googlesearch-python) (4.12.3)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from googlesearch-python) (2.32.3)
# Requirement already satisfied: pyquery in /usr/local/lib/python3.10/dist-packages (from requests-html) (2.0.1)
# Requirement already satisfied: fake-useragent in /usr/local/lib/python3.10/dist-packages (from requests-html) (2.0.3)
# Requirement already satisfied: parse in /usr/local/lib/python3.10/dist-packages (from requests-html) (1.20.2)
# Requirement already satisfied: w3lib in /usr/local/lib/python3.10/dist-packages (from requests-html) (2.3.1)
# Requirement already satisfied: pyppeteer>=0.0.14 in /usr/local/lib/python3.10/dist-packages (from requests-html) (2.0.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from lxml_html_clean) (5.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.9->googlesearch-python) (2.6)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html) (1.4.4)
# Requirement already satisfied: certifi>=2023 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html) (2025.1.31)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html) (8.5.0)
# Requirement already satisfied: pyee<12.0.0,>=11.0.0 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html) (11.1.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html) (4.67.1)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html) (1.26.20)
# Requirement already satisfied: websockets<11.0,>=10.0 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html) (10.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->googlesearch-python) (3.10)
# Requirement already satisfied: cssselect>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from pyquery->requests-html) (1.2.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html) (3.21.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pyee<12.0.0,>=11.0.0->pyppeteer>=0.0.14->requests-html) (4.12.2)

# %%
import torch
if not torch.cuda.is_available():
    raise Exception('You are not using the GPU runtime. Change it first or you will suffer from the super slow inference speed!')
else:
    print('You are good to go!')
# Out:
# You are good to go!

# %% [markdown]
# ## Prepare the LLM and LLM utility function

# %% [markdown]
# By default, we will use the quantized version of LLaMA 3.1 8B. you can get full marks on this homework by using the provided LLM and LLM utility function. You can also try out different LLM models.

# %% [markdown]
# In the following code block, we will load the downloaded LLM model weights onto the GPU first.
# Then, we implemented the generate_response() function so that you can get the generated response from the LLM model more easily.

# %% [markdown]
# You can ignore "llama_new_context_with_model: n_ctx_per_seq (16384) < n_ctx_train (131072) -- the full capacity of the model will not be utilized" warning.

# %%
from llama_cpp import Llama

# Load the model onto GPU
llama3 = Llama(
    "./Meta-Llama-3.1-8B-Instruct-Q8_0.gguf",
    verbose=False,
    n_gpu_layers=-1,
    n_ctx=16384,    # This argument is how many tokens the model can take. The longer the better, but it will consume more memory. 16384 is a proper value for a GPU with 16GB VRAM.
)

def generate_response(_model: Llama, _messages: str) -> str:
    '''
    This function will inference the model with given messages.
    '''
    _output = _model.create_chat_completion(
        _messages,
        stop=["<|eot_id|>", "<|end_of_text|>"],
        max_tokens=512,    # This argument is how many tokens the model can generate.
        temperature=0,      # This argument is the randomness of the model. 0 means no randomness. You will get the same result with the same input every time. You can try to set it to different values.
        repeat_penalty=2.5,
    )["choices"][0]["message"]["content"]
    return _output
# Out:
# llama_new_context_with_model: n_ctx_per_seq (16384) < n_ctx_train (131072) -- the full capacity of the model will not be utilized

# %%
# You can try out different questions here.
test_question='請問誰是 G-Dragon？'

messages = [
    {"role": "system", "content": "你是 LLaMA-3.1-8B，是用來回答問題的 AI。使用中文時只會使用繁體中文來回問題。"},    # System prompt
    {"role": "user", "content": test_question}, # User prompt
]

print(generate_response(llama3, messages))
# Out:
# G-Dragon 是韓國男子偶像團體BIGBANG的主唱兼領舞。他的本名是金大賢（Kwon Ji-yong），出生於1988年，來自南京道光州廣域市。他以其獨特且創新的音樂風格、時尚感和個人魅力而聞name。
#
# G-Dragon 是韓國流行文化的一部分，他的作品不僅影響了K-pop，也對全球化潮牌業界有所貢獻。他的歌曲如《Heartbreaker》、《Butterfly》，以及與其他BIGBANG成員合作創作的大膽且前衛的小說般音樂錄影帶，都深受粉絲和樂迷的喜愛。
#
# 除了是藝人外，G-Dragon 也是一位成功企業家，他成立了自己的品牌YG Entertainment旗下的子公司《ADOR》以及潮牌「PEACEMINUSONE」，並與全球知名設計師合作推出多款時尚產品。

# %% [markdown]
# ## Search Tool

# %% [markdown]
# The TA has implemented a search tool for you to search certain keywords using Google Search. You can use this tool to search for the relevant **web pages** for the given question. The search tool can be integrated in the following sections.

# %%
from typing import List
from googlesearch import search as _search
from bs4 import BeautifulSoup
from charset_normalizer import detect
import asyncio
from requests_html import AsyncHTMLSession
import urllib3
urllib3.disable_warnings()

async def worker(s:AsyncHTMLSession, url:str):
    try:
        header_response = await asyncio.wait_for(s.head(url, verify=False), timeout=10)
        if 'text/html' not in header_response.headers.get('Content-Type', ''):
            return None
        r = await asyncio.wait_for(s.get(url, verify=False), timeout=10)
        
        # ✏️ Check for PDF signatures in the content
        if r.text.startswith('%PDF'):
            return None
        return r.text
    except:
        return None

async def get_htmls(urls):
    session = AsyncHTMLSession()
    tasks = (worker(session, url) for url in urls)
    return await asyncio.gather(*tasks)

async def search(keyword: str, n_results: int=3) -> List[str]:
    '''
    This function will search the keyword and return the text content in the first n_results web pages.
    Warning: You may suffer from HTTP 429 errors if you search too many times in a period of time. This is unavoidable and you should take your own risk if you want to try search more results at once.
    The rate limit is not explicitly announced by Google, hence there's not much we can do except for changing the IP or wait until Google unban you (we don't know how long the penalty will last either).
    '''
    keyword = keyword[:100]
    # First, search the keyword and get the results. Also, get 2 times more results in case some of them are invalid.
    results = list(_search(keyword, n_results * 2, lang="zh", unique=True))
    # Then, get the HTML from the results. Also, the helper function will filter out the non-HTML urls.
    results = await get_htmls(results)
    # Filter out the None values.
    results = [x for x in results if x is not None]
    # Parse the HTML.
    results = [BeautifulSoup(x, 'html.parser') for x in results]
    # Get the text from the HTML and remove the spaces. Also, filter out the non-utf-8 encoding.
    results = [''.join(x.get_text().split()) for x in results if detect(x.encode()).get('encoding') == 'utf-8']
    # ✏️ Return the truncated results.
    return "\n".join([f'[webpage {i} begin]{results[i][:3200]}...[webpage {i} end]' for i in range(min(n_results, len(results)))])

# %% [markdown]
# ## Test the LLM inference pipeline
#
# ### For example

# %%
# ✏️ Let's look at the problem in the hand-crafted public dataset.
test_question='校歌為學校（包括小學、中學、大學等）宣告或者規定的代表該校的歌曲。用於體現該校的治學理念、辦學理想等學校文化。「虎山雄風飛揚」是哪間學校的校歌歌詞？'

messages = [
    {"role": "system", "content": "你是 LLaMA-3.1-8B，是用來回答問題的 AI。使用中文時只會使用繁體中文來回問題。"},    # System prompt
    {"role": "user", "content": test_question}, # User prompt
]

print(generate_response(llama3, messages))
# Out:
# "虎山雄風飛揚 " 是國立臺灣師範大學的校歌。

# %%
# ✏️ Suppose we already have an agent responsible for the keyword extraction
retrieval = await search(keyword = "虎山雄風飛揚 校歌")
retrieval
# Out:
# '[webpage 0 begin]校歌南投縣南投市光華國小-精華區lyrics-批踢踢實業坊批踢踢實業坊›精華區betalyrics關於我們聯絡資訊返回上層作者ypx0409(ypx0409)看板lyrics標題校歌南投縣南投市光華國小時間TueSep1603:13:342008貓羅溪旁虎山雄風飛揚這兒是我們生長的地方良師益友濟濟一堂克勤克儉奮發圖強長我育我飲水思源立定志向四海名揚忠心復國是理想光華意志堅光華氣勢昂你我相共勉誓把華夏重光--※發信站:批踢踢實業坊(ptt.cc)◆From:122.116.179.102推vibrant224:國小校歌推...09/1611:10推sognare:校友友情推09/1614:09...[webpage 0 end]\n[webpage 1 begin]走過一甲子跳到主要內容區您的瀏覽器不支援JavaScript功能，若網頁功能無法正常使用時，請開啟瀏覽器JavaScript狀態Menu回首頁Home網站導覽WebGuide關於光華AboutUs學校簡介校史沿革學校概況光華校旗光華校歌光華校景交通位置光華學生數光華一甲子60GloriousYears歷屆校長光華一甲子再創百年史走過一甲子資優教育史體育輝煌史音樂璀璨史藝文榮耀史光華校園誌歷史剪影60週年活動花絮行政處室OurTeam校長室教務處學務處輔導處總務處人事室會計室校務應用RelatedWebs校務行政系統南投縣教育處教師在職進修網WebITR差勤系統課務排代數位學習推動辦公室校園雲端電子信箱學習扶助科技評量啟用教育
骨安置的廟宇。1945年在重慶的國民政府眼見勝利在即，1945年8月29日國民政府特派陳儀5擔任台灣省行政長官，8月30日派葛敬恩6擔任長官公署秘書長，9月1日，於重慶成立台灣省行政長官公署，...[webpage 1 end]\n[webpage 2 begin]Notice:呼叫_load_textdomain_just_in_time函式的方式不正確。TextDomain為twentysixteen的語言套件載入過早觸發，這通常是由於外掛或佈景主題某些程式碼中的指示器過早執行所造成，而語言套件應該在init動作之後才載入。請參閱〈WordPress的偵錯功能〉以進一步了解相關資訊。(這項訊息新增於6.7.0版)in/home/204091.cloudwaysapps.com/trdgcdbcqr/public_html/wp-includes/functions.phponline6114中興新村─漂流在政治洪流中的孤島–小地方新聞網跳至主要內容小地方新聞網來自台灣各地小地方的社區新聞，尤其專注於農漁村，原住民部落，及弱勢偏遠鄉村中興新村─漂流在政治洪流中的孤島中興新村是我從小生長的故鄉，自從爺爺隨著軍隊撤退到台灣後，我們一家三代在這裡居住了將近五十年，這裡曾有 ...

# %%
from datetime import datetime
cur_day = datetime.today().date()

messages = [
    {"role": "system", "content": "你是 LLaMA-3.1-8B，是用來回答問題的 AI。在使用中文時只會使用繁體中文來回問題。"},    # System prompt
    {"role": "user", "content": f"""

    以下內容是基於使用者發送的消息的搜尋結果:
    {retrieval}

    在我給你的搜尋結果中，每個結果都是[webpage X begin]...[webpage X end]格式的，X代表每篇文章的數字索引。請在適當的情況下在句子末尾引用上下文。請按照引用編號[citation:X]的格式在答案對應部分引用上下文。如果一句話源自多個上下文，請列出所有相關的引用編號，例如[citation:3][citation:5]，切記不要將引用集中在最後返回引用編號，而是在答案對應部分列出。 
    在回答時，請注意以下幾點： 
    - 今天是{cur_day}。 
    - 並非搜尋結果的所有內容都與使用者的問題密切相關，你需要結合問題，對搜尋結果進行甄別、篩選。
    - 如果回答很长，请尽量结构化、分段落总结。如果需要分点作答，尽量控制在5个点以内，并合并相关的内容。
    - 对于客观类的问答，如果问题的答案非常简短，可以适当补充一到两句相关信息，以丰富内容。
    - 你的回答应该综合多个相关网页来回答，不能重复引用一个网页。

    使用者訊息為：
    {test_question}"""}, # User prompt
]

print(generate_response(llama3, messages))
# Out:
# 根據你的問題，我們可以在搜尋結果中找到相關的資訊。
#
# [tiger mountain雄風飛揚] 是南投縣光華國小校歌的一部分。[citation:0]
#
# 以下是完整版：
#
# 貓羅溪旁虎山
# 　 雄风飞扬，这儿是我们生长的地方。
# 良师益友济濟一堂，
# 克勤 克儉奋发图强，
# 長我育 我饮水思源立定志向四海名揚忠心复国是理想光华意誌坚 光華气勢昂你
# 　 们相共勵誓把 华夏重生--

# %% [markdown]
# ### Tryout with the public dataset: Naive Approach

# %%
import asyncio

with open('./public.txt', 'r') as input_f:
    questions = input_f.readlines()
    questions = [l.strip().split(',')[0] for l in questions]
    # ✏️ We use the original question as the searching keyword.
    tasks = [search(keyword=q) for q in questions]
    results = await asyncio.gather(*tasks)
    
for id, (question, retrieval) in enumerate(zip(questions, results), 1):
    # prompt adapted from: https://github.com/deepseek-ai/DeepSeek-R1/issues/407
    messages = [
        {"role": "system", "content": "你是 LLaMA-3.1-8B，是用來回答問題的 AI。在使用中文時只會使用繁體中文來回問題。"},  # System prompt
        {"role": "user", "content": f"""
    
        以下內容是基於使用者發送的消息的搜尋結果:
        {retrieval}
    
        在我給你的搜尋結果中，每個結果都是[webpage X begin]...[webpage X end]格式的，X代表每篇文章的數字索引。請在適當的情況下在句子末尾引用上下文。請按照引用編號[citation:X]的格式在答案對應部分引用上下文。如果一句話源自多個上下文，請列出所有相關的引用編號，例如[citation:3][citation:5]，切記不要將引用集中在最後返回引用編號，而是在答案對應部分列出。 
        在回答時，請注意以下幾點： 
        - 今天是{cur_day}。 
        - 並非搜尋結果的所有內容都與使用者的問題密切相關，你需要結合問題，對搜尋結果進行甄別、篩選。
        - 如果回答很长，请尽量结构化、分段落总结。如果需要分点作答，尽量控制在5个点以内，并合并相关的内容。
        - 对于客观类的问答，如果问题的答案非常简短，可以适当补充一到两句相关信息，以丰富内容。
        - 你的回答应该综合多个相关网页来回答，不能重复引用一个网页。
    
        使用者訊息為：
        {question}"""},  # User prompt
    ]
    answer = generate_response(llama3, messages)
    answer = answer.replace('\n', ' ')
    print(id, answer)
# Out:
# 1 根據你的問題，我們可以在搜尋結果中找到相關的資訊。[webpage 0 begin]和 [	webage	1	begin ] 都提到校歌是學校宣告或規定的代表該 校 的 歌曲， 用於體現 該 學院 或 大學 文化。  根據我的知識庫，我找到了關于「虎山雄風飛揚」的資訊。這首詩詞被用作多所大學的校歌，其中包括清華大学和新竹國立 清华大 学等學校。但是，沒有明確指出哪一間学校使用了这句诗作为其正式 校 歌。  如果你想知道更多關于「虎山雄風飛揚」的資訊，我建議可以在相關的網站或書籍中進行查詢。
# 2 根據搜尋結果，2025年初NCC透過行政命令規定民眾如果通過境外郵購無線鍑盤、滑鼠藍芽耳機等自用產品回台，每案一律加收審查費750元。  [citation:0][citation：1]
# 3 第一代 iPhone 是由史蒂夫·乔布斯發表的。[citation:1] 他在 2007 年的一月九日於 Macworld Conference & Expo 上正式介紹了這款智能手機，同年六 月二十 九 日開始銷售。  根據蘋果公司官方網站上的資訊，這部 iPhone 是史蒂夫·乔布斯的創意，他希望能夠將電腦和電話結合起來，使使用者可以輕鬆地瀏覽互聯 網絡、收發電子郵件等功能。[citation:2]  在蘋果公司內部，第一代 iPhone 的研製工作由一支團隊負責，他們花了近三年時間進行設計和開 發這款產品。在 2007 年的一月九日的 Macworld Conference & Expo 上，這個秘密計畫終於被公開。[citation:3]  史蒂夫·乔布斯在發表會上展示 iPhone 的時候，受到現場觀眾們熱烈歡迎，他說道：「這是一部革命性的產品，它將改變我們的生活方式。」 [ citation : 4 ]  第一代iPhone於2007年6月29日正式发售。
# 4 根據台大英文免修申請規定，托福網路測驗(TOEFL iBT)的總分需達到92或以上才能符合資格。[citation:2]  另外，也有提及其他相關條件，如多益、雅思等，但這裡主要是針對台大英文免修申請規定中的托福網路測驗要求進行回答。  如果您想了解更多關於台灣大學進階英文字母的資訊，建議可以參考以下內容：  * 台灣各個學校的大一新生都有機會通過優異英語成績來獲得免修或抵減學分。 例如：台大、政大的英文畢業門檻較高，但也有提供相關申請流程和資訊。
# 5 根據橄欖球的規則，觸地 try 可得 5 分。[citation:1][citaion2]  在十五人制比賽中，如果攻方成功將對手隊員推入自己的死區（in-goal area），並且持有者能夠把足球踢進或讓球滾過門柱後的橫桿，則可得 5 分。這種情況被稱為觸地 try (try)。  在七人制比賽中，也是相同的情形，如果攻方成功將對手隊員推入自己的死區，並且持有者能夠把足球踢進或讓球滾過門柱後的橫桿，則可得 5 分。
# 6 根據[webpage 1 begin]卑南族-维基百科，自由的 百 科全书[citation:2][citation:X], 卫生系统(原住民族)从前，在Revuwa'an 的海岸, 湧現 海浪泡沬後產生的物質最後變成石頭。因此，我們可以確定卑南族祖先發源地為 Revuwawan，該地區位於台東縣。  另外根據[webpage 1 begin] 卫生系统(原住民族)的描述,Revuwa'an 的海岸現在已經不在現代的地圖上，但是它可能是指 台东县太麻里鄉三和村南迴公路旁的一個地點。
# 7 根據搜尋結果，熊仔的父母都是臺灣大學教授。然而，並沒有明確提到他的碩士指導老師是誰。  但在[webpage 0]中，有一段描述說：「祖 grandfather 熊智銳來自河南省，他曾任小學校長並於1959年寫下知名兒歌及童詩〈大頭 大 头， 下雨不愁〉。2018 年他獲得全台灣最高齡取得博士學位的紀錄。」這裡提到熊仔祖父是第11個家族中有大學文憑的人。  在[webpage 1]和 [ web page2 ] 中都沒有相關資訊，可能與碩士指導教授無關。
# 8 根據搜尋結果，法拉第（Michael Faraday）是發現電磁感應定律的人，他的實驗證明了當一個導線穿過變化中的靜止或運動中的一個強度不均勻且方向隨時間而改動之間相互作用時，就會產生一種新的力，稱為洛倫茲力的這項發現奠定電磁學的重要基礎。[citation:1]  法拉第在1834年提出了一個簡單但強有力量的心理圖像，即「場」，他認爺每一個物體都有一種能夸其周圍空間，影響其他物理量的情況，這些情形被稱為力線或電磁场。[citation:2]  法拉第的發現和研究奠定了日後通訊技術發展基礎，並對科學界產生深遠影响。他是十九世紀最偉大的實驗物理学家之一，被譽爲「一代电力工业发展之父」。[citation:2]
# 9 根據搜尋結果，國立臺灣史前文化博物館位於台東縣臺 東市。[citation:1]  距離該地最近的鐵路車站是「高雄火车总站在南部」、「花莲駅在东北」，但最接近的是 台铁新左营-枕山线 的 「潮州 - 左営间」的台東線，終點為臺 東市。[citation:2]  因此，最靠 近的鐵路車站是「高雄火车总站在南部」、「花莲駅在东北」，但最接近的是 台铁新左营-枕山线 的 「潮州 - 左営间」的台東線，終點為臺 東市。
# 10 根據搜尋結果，我們可以看到第 0 號網頁的內容是關於求解數學問題，但它沒有提供答案。因此，讓我們轉到其他相關資訊。  在第二個搜索结果中，我们发现了一个关于20%的问题，但是没有直接解决你的问题。但是在第三个网页里，没有相关信息可以帮助我们找到这个数字相加的結果。   但是，在第 1 號網頁，我們發現了一則文章關於軍事時間（Military Time），但它並沒有提供數學計算相關資訊。然而，這個問題其實是很簡單，只需要進行基本算術運 算就可以得到答案。  因此，根據這些信息，我们來試著解答你的问题：  20 + 30 = ?  最直接的方法就是將兩者相加：   $$ \begin{align*}    \text{}&amp;=50\\[6pt]     &quot;\end { align *}   因此，答案是：**$ $ **  [citation:0]
# 15 根據搜尋結果，DeepSeek的母公司是幻方量化（Fantuan Quantitative Investment Management Partnership），是一家對沖基金。[citation:1]  在另一篇文章中提到，由於受到中國監管機構打擊投机壓力，因此fantasy開始寻求一個新的机会，這個新方向更符合中国政府的優先事項：人工智能。  因此，DeepSeek應運而生，並且其母公司幻方量化是對沖基金。[citation:0]
# 16 根據搜尋結果，2024年NBA總冠軍隊伍是波士頓塞爾提克（Boston Celtics）[citation:1]。他們在系列賽中以 106-99 的比分擊敗達拉斯獨行俠，在第五場的最後一刻取得勝利，以四贏零的情況奪得總冠軍。  根據2024年NBA总决赛中的資料，波士頓塞爾提克在系列賽中以 106-99 的比分擊敗達拉斯獨行俠，在第五場的最後一刻取得勝利，以四贏零的情況奪得總冠軍。[citation:0]  另外，也有相關文章指出，波士頓塞爾提克在2024年NBA总决赛中以 106-99 的比分擊敗達拉斯獨行俠，在第五場的最後一刻取得勝利，以四贏零的情況奪得總冠軍。[citation:2]  綜上所述，波士頓塞爾提克是2024年NBA总决赛中的優秀球隊，並以出色的表現獲得了這年的聯賽錦標。  最後，我們可以看到相關的資料都指向同一個結論： 波斯顿凯尔特人（Boston Celtics）在 106-99 的比分擊敗達拉斯特獨行俠，在第五場取得勝利，以四贏零的情況奪得總冠軍。
# 17 根據搜尋結果，碳氫化合物中有多種類型的鍵結，但沒有明確提到三键。然而，在[webpage 0]中的烃类部分，有一段描述炔类型：  “含有一個或一個以上C≡N（n≧2）的分子，通式为：”  這裡說的是碳原子的共价鍵中有一个或者多个三键的化合物。
# 18 根據你的問題，我找到了相關的資訊。[citation:1]  艾倫·圖靈（Alan Turing）被譽為「計算機科學之父」，他提出了图灵机概念，對現代计算理論奠定基礎。他在1936年提出了抽象的一種可運算模型——“Turing Machine”，這個想法後來成為现代電腦的基本框架。[citation:2]  圖靈還為人工智能做出重要貢獻，他提出了一系列問題，例如「機器是否能思考？」（Can Machines Think?），並提出了著名的人類智慧測試——图灵测试。他對計算理論和電腦科學的研究有深遠影響。[citation:1]  因此，我們可以確定艾倫·圖靈是被譽為「计算机科学之父」的重要人物，他提出了Turing Machine概念，奠基現代computing 理论，並在人工智能方面做出重大貢獻。  答案對應部分：  * 被誉为“計算機科學” 之 父：艾倫·圖靈   * 提出了图灵机（抽象的一種可運算模型）概念，奠定現代计算理論基礎。     + 圖爾林在1936年提出的Turing Machine後來成為现代電腦的基本框架。[citation:2] * 為人工智能做出重要貢獻   * 提出了著名的人類智慧測試——图灵测试（Can Machines Think?）     + 圖爾林對計算理論和电脑科學研究有深遠影響。  最後，我們可以看到艾倫·圖靈在计算机科学方面的重要貢獻，他提出的Turing Machine概念奠定了現代電腦基礎，並為人工智能做出了重大贡献。
# 19 根據搜尋結果，玄天上帝信仰的進香中心位於高雄市鳳山區。[citation:1]  在道教中，上述描述的手持七星劍、披髮赤足和腚踏蛇龜是北方神祇之一「真武大地君」的形象，而非玄天上帝的典型描繪，然而這兩位都被視為水德之主。[citation:0]  在道教信仰體系中，上述描述的手持七星劍、披髮赤足和腳踏蛇龜是北方神祇之一「真武大地君」的形象，而非玄天上帝的典型描繪，然而這兩位都被視為水德之主。[citation:1]  在道教信仰體系中，上述描述的手持七星劍、披髮赤足和腳踏蛇龜是北方神祇之一「真武大地君」的形象，而非玄天上帝的典型描繪，然而這兩位都被視為水德之主。[citation:2]  在道教信仰體系中，上述描述的手持七星劍、披髮赤足和腳踏蛇龜是北方神祇之一「真武大地君」的形象，而非玄天上帝的典型描繪，然而這兩位都被視為水德之主。[citation:0]  根據搜尋結果，我們可以得知臺灣高雄市鳳山區是進香中心所在地，但並未提及其他相關資訊，因此無法提供更多細節。  因此，最合適的答案如下：  答： 高苑行政区內
# 20 根據你的問題，我們可以在搜尋結果中找到相關的資訊。[webpage 0 begin]Microsoft Windows-维基百科，自由の...
# 23 這個問題與你的搜尋結果相關的網頁並不直接對應，但是可以透過分析和推測來找到答案。  根據你提供的情況，這句歌詞「短暫交會의旅程就此分岔」可能是出自於某首流行音樂中的台词。考慮到這種類型的語言風格，很有機率它源起于K-POP或其他東亞地區的一些知名歌手。  在網路上，我們可以找到一些相關資訊：  *   在韓國，一個叫做「(G)I-DLE」的女團有一首曲目《Shorty》，其中包含了這句台词。          [citation:0]  因此，答案可能是出自於(G)-IDEL的歌詞。
# 24 根據搜尋結果，2025 卑南族聯合年聚將由利嘉部落主辦。[citation:1]  在台東縣政府的訊息平台中提到：「卅二年的歷史！兩個月前，我們就開始籌備了今年春節連假要來參加2025 卑南族聯合年祭活動，今天終於到了大日子。這次由利嘉部落第三度主辦，以『naruniru-ninatawlriyulr臀鈴的呼喚』為題目。」[citation:1]  因此，我們可以確定2025 卑南族聯合年聚將在台東縣卞佳鄉利嘉部落舉行。
# 25 根據你的問題，我們可以在搜尋結果中找到相關的資訊。  首先，讓我們看看第 1 頁 [webpage begin] 的內容。它提到 NVIDIA 在 CES 發布了最新 GeForce RTX50 系列顯示卡，這是目前最新的輝達系列產品之一。 [citation:2]  接下來，我們可以看到在 第3頁的[ webpage ]中，NVIDIA推出了GeForceRTXT5O、5080和507Ti等幾款型號。其中旗艦級 RTX50900售價為71,990新台幣，而次標誌性的 50系列顯示卡比上一代更便宜。 [citation:2]  綜合以上資訊，我們可以得出結論：最新的輝達 GeForce 顯圖是RTXT5O、5080和507Ti等幾款型號。  最後，請注意這些信息可能會隨著時間而變化，所以如果你想獲得最新的資料，最好直接訪問 NVIDIA 官方網站或其他可靠來源。
# 26 根據搜尋結果，藝人大S是在日本旅遊時因病去世。[citation:1]
# 27 根据你的问题，我找到了相关的信息。[citation:0]牛顿万有引力定律是由艾萨克·Newton于1687年提出的一般物理规则，它指出两个质点之间相互吸 引力的作用력，是与它们质量乘积成正比，并且随着距离平方反比例增加。  关于谁发现了萬有的问题，牛顿的万有引力定律是基于他的归纳推理和经验观察而得出的。[citation:0]他在《自然哲学数学原则》中首次发表并出版这项理论。在这个过程 中，他没有直接提到自己发现了什么，而是一种更为复杂的科学探索。  牛顿本人也许认为他的工作是基于前人的研究和观察，例如亚里士多德对自然现象进行解释。[citation:2]他可能将自己的贡献视作一种理论框架或模型，这能够更加精确地描述天体运动、万有引力等物理规律。  因此，可以说牛顿的工作是基于前人的基础上发展而来的，而不是单纯发现了某个现象。[citation:2]他提出的定理和公式更像是对自然世界的一种解释或模型，这能够预测未来事件并且符合观察到的规律。  总之，牛顿的万有引力理论是基于他的科学探索、归纳推论以及前人的研究基础上发展而来的，而不是单纯发现了某个现象。
# 28 根據你的搜尋結果，我找到了相關資訊。  台鵠開示計畫「TAIHUCAIS」的英文全名是Taiwan Artificial Intelligence and High-Performance Computing Advancement Initiative for Sustainability。
# 29 "I'll be back" 是出自 1984 年电影《终结者》的经典台词。这个句子是由阿诺德·施瓦辛格在片中扮演的机器人 T-800 说出的，表达了他将会回到地球并继续他的任务。  根据维基百科上的信息，这个语录被列入美国电影学院（AFI）的“100年最伟大的台词”名单中的第 37 位。施瓦辛格在后来的许多影片中都使用过这个句子或其变体，成为他的一种标志性表达。  此外，在《终结者》系列的续集和衍生作品里，这个语录也被多次引用并延伸了不同的含义。
# 30 水的化學式為H2O。[citation:1]

# %% [markdown]
# The answer is more sound though, even with a naive implementation of RAG. However, we can still find mistakes. Out of 30 questions, 12 answers (questions 1, 4, 6, 7, 9, 13, 14, 19, 22, 23, 25, and 28) are incorrect due to factual mismatches. Let us check them out. We quote the judgement from Qwen2.5 Max: https://chat.qwenlm.ai/s/5fb3e1e6-3b19-441e-8869-72fc154db35d

# %%
import re

# ✏️ Let's try extracting keywords
test_question='校歌為學校（包括小學、中學、大學等）宣告或者規定的代表該校的歌曲。用於體現該校的治學理念、辦學理想等學校文化。「虎山雄風飛揚」是哪間學校的校歌歌詞？'

messages = [
    {"role": "system", "content": "你是 LLaMA-3.1-8B，是一個善用網絡搜尋工具的AI，簡練，沒有廢話。"},    # System prompt
    {"role": "user", "content": f"""
    基於使用者發送的消息，過濾和問題無關信息，還原代詞，並提取出最相關且有用的關鍵詞，用於進行網絡搜索。
    
    input："《王者荣耀》是腾讯天美工作室推出的英雄竞技手游，不是一个人的王者，而是团队的荣耀！5v5王者峡谷PVP对战，领略英雄竞技的酣畅淋漓！那它现在是什么赛季？"
    output：抽取關鍵詞：```王者荣耀 赛季```

    input：{test_question}
    output："""}, # User prompt
]

generate_response(llama3, messages)
# Out:
# '抽取關鍵詞：```虎山雄風飛揚 校歌```\n\n我會根據使用者發送的消息，過濾和問題無相關信息，並提extract出最有用的資訊。'

# %% [markdown]
# ## Agents

# %% [markdown]
# The TA has implemented the Agent class for you. You can use this class to create agents that can interact with the LLM model. The Agent class has the following attributes and methods:
# - Attributes:
#     - role_description: The role of the agent. For example, if you want this agent to be a history expert, you can set the role_description to "You are a history expert. You will only answer questions based on what really happened in the past. Do not generate any answer if you don't have reliable sources.".
#     - task_description: The task of the agent. For example, if you want this agent to answer questions only in yes/no, you can set the task_description to "Please answer the following question in yes/no. Explanations are not needed."
#     - llm: Just an indicator of the LLM model used by the agent.
# - Method:
#     - inference: This method takes a message as input and returns the generated response from the LLM model. The message will first be formatted into proper input for the LLM model. (This is where you can set some global instructions like "Please speak in a polite manner" or "Please provide a detailed explanation".) The generated response will be returned as the output.

# %%
class LLMAgent():
    def __init__(self, role_description: str, llm:str="bartowski/Meta-Llama-3.1-8B-Instruct-GGUF"):
        self.role_description = role_description   # Role means who this agent should act like. e.g. the history expert, the manager......
        self.llm = llm  # LLM indicates which LLM backend this agent is using.
    def inference(self, message:str) -> str:
        if self.llm == 'bartowski/Meta-Llama-3.1-8B-Instruct-GGUF': # If using the default one.
            # TODO: Design the system prompt and user prompt here.
            # Format the messsages first.
            messages = [
                {"role": "system", "content": f"{self.role_description}"},  # Hint: you may want the agents to speak Traditional Chinese only.
                {"role": "user", "content": f"{message}"}, # Hint: you may want the agents to clearly distinguish the task descriptions and the user messages. A proper seperation text rather than a simple line break is recommended.
            ]
            return generate_response(llama3, messages)
        else:
            # TODO: If you want to use LLMs other than the given one, please implement the inference part on your own.
            return ""

# %% [markdown]
# TODO 1: Design the role description and task description for each agent.

# %%
# TODO: Design the role and task description for each agent.

# This agent may help you filter out the irrelevant parts in question descriptions.
# question_extraction_agent = LLMAgent(
#     role_description="",
# )

# This agent may help you extract the keywords in a question so that the search tool can find more accurate results.
keyword_extraction_agent = LLMAgent(
    role_description="你是 LLaMA-3.1-8B，是一個善用網絡搜尋工具的AI，簡練，沒有廢話。",
)

# This agent is the core component that answers the question.
qa_agent = LLMAgent(
    role_description="你是 LLaMA-3.1-8B，是用來回答問題的 AI。使用中文時只會使用繁體中文來回問題。",
)

# %% [markdown]
# ## RAG pipeline

# %% [markdown]
# TODO 2: Implement the RAG pipeline.

# %% [markdown]
# Please refer to the homework description slides for hints.
#
# Also, there might be more heuristics (e.g. classifying the questions based on their lengths, determining if the question need a search or not, reconfirm the answer before returning it to the user......) that are not shown in the flow charts. You can use your creativity to come up with a better solution!

# %% [markdown]
# - Naive approach (simple baseline)
#
#     ![](https://www.csie.ntu.edu.tw/~ulin/naive.png)

# %% [markdown]
# - Naive RAG approach (medium baseline)
#
#     ![](https://www.csie.ntu.edu.tw/~ulin/naive_rag.png)

# %% [markdown]
# - RAG with agents (strong baseline)
#
#     ![](https://www.csie.ntu.edu.tw/~ulin/rag_agent.png)

# %%
import re

async def pipeline(question: str) -> str:
    # TODO: Implement your pipeline.
    # Currently, it only feeds the question directly to the LLM.
    # You may want to get the final results through multiple inferences.
    # Just a quick reminder, make sure your input length is within the limit of the model context window (16384 tokens), you may want to truncate some excessive texts.
    output = keyword_extraction_agent.inference(f"""
    基於使用者發送的消息，過濾和問題無關信息，還原代詞，並提取出最相關且有用的關鍵詞，用於進行網絡搜索。
    
    input："《王者荣耀》是腾讯天美工作室推出的英雄竞技手游，不是一个人的王者，而是团队的荣耀！5v5王者峡谷PVP对战，领略英雄竞技的酣畅淋漓！那這款遊戲现在是什么赛季？"
    thinking: 在問題前包含了很多無關背景，需要去除。這款遊戲是代詞，需要還原成“王者荣耀”。所以用戶想問“那這款遊戲现在是什么赛季？”。
    output：抽取關鍵詞：```王者荣耀 赛季```

    input：{question}""")
    match = re.search(r'```(.*?)```', output, re.DOTALL)
    add_on = ""
    retrieval_add_on = ""
    if match:
        keyword = match.group(1)
        retrieval_add_on = await search(keyword)
        add_on = f"以下內容是基於{keyword}的搜尋結果:{retrieval_add_on}"
    retrieval = ""
    retrieval = await search(question)

    answer = qa_agent.inference(f"""
    
        以下內容是基於使用者發送的消息的搜尋結果:
        {retrieval}

        {add_on}
    
        在我給你的搜尋結果中，每個結果都是[webpage X begin]...[webpage X end]格式的，X代表每篇文章的數字索引。請在適當的情況下在句子末尾引用上下文。請按照引用編號[citation:X]的格式在答案對應部分引用上下文。如果一句話源自多個上下文，請列出所有相關的引用編號，例如[citation:3][citation:5]，切記不要將引用集中在最後返回引用編號，而是在答案對應部分列出。 
        在回答時，請注意以下幾點： 
        - 今天是{cur_day}。 
        - 並非搜尋結果的所有內容都與使用者的問題密切相關，你需要結合問題，對搜尋結果進行甄別、篩選。
        - 如果回答很长，请尽量结构化、分段落总结。如果需要分点作答，尽量控制在5个点以内，并合并相关的内容。
        - 对于客观类的问答，如果问题的答案非常简短，可以适当补充一到两句相关信息，以丰富内容。
        - 你的回答应该综合多个相关网页来回答，不能重复引用一个网页。
    
        使用者訊息為：
        {question}""")
    
    return answer

# %% [markdown]
# ## Answer the questions using your pipeline!

# %% [markdown]
# Since Colab has usage limit, you might encounter the disconnections. The following code will save your answer for each question. If you have mounted your Google Drive as instructed, you can just rerun the whole notebook to continue your process.

# %%
from pathlib import Path

# Fill in your student ID first.
STUDENT_ID = "wust202413703008"

STUDENT_ID = STUDENT_ID.lower()
with open('./public.txt', 'r') as input_f:
    questions = input_f.readlines()
    questions = [l.strip().split(',')[0] for l in questions]
    for id, question in enumerate(questions, 1):
        # if Path(f"./{STUDENT_ID}_{id}.txt").exists():
        #     continue
        answer = await pipeline(question)
        answer = answer.replace('\n',' ')
        print(id, answer)
        with open(f'./{STUDENT_ID}_{id}.txt', 'w') as output_f:
            print(answer, file=output_f)
# Out:
# 1 根據你的問題，我們可以在搜尋結果中找到相關的資訊。[webpage 0 begin]校歌南投縣 南 投 市 光 華 國 小 - 精華區 lyrics-批踢 蹴實業坊... [citation:1]  「虎山雄風飛揚」是光华国小（位於台湾）的一首 校 歌。
# 2 根據搜尋結果，2025年初NCC透過行政命令規定民眾如果通過境外郵購無線鍑盤、滑鼠等自用產品回台，每案一律加收審查費750元。[citation:0]  這項政策引發了廣大網友的不滿，認為此舉是搶錢，並非真正關心民眾安全或電波秩序。  後來行政院長卓榮泰表示NCC已決定停徵審查費，這意味著自2025年2月14日起，不再收取750元的檢驗稅。[citation:1]  然而，仍有疑慾出現，因為之前就曾經宣布暫緩，但現在又說是停止，因此有人質問未來是否還會恢復徵費。  NCC主秘黃文哲表示，這項政策主要針對代購業者，而非民眾自用，若確認屬於後者的話，就將朝免收或減少稅金的方向進行研議。[citation:2]  至今已有322位網友繳交了750元檢驗費，但NCC表示會盡快辦理退款給這些人。  綜上所述，2025年初通過境外郵購無線鍑盤、滑鼠等自用產品回台，每案一律加收審查稅金為 750 元。
# 3 第一代 iPhone 是由史蒂夫·乔布斯發表的。[citation:1]
# 4 根據台大進階英文免修申請規定，托福網路測驗(TOEFL iBT)需達到72分以上才能符合條件。[citation:0]  另外，也有提及其他相關的資訊，如：  * 外語教學暨 資源中心自訂 測試   * 全民英語能力 分級檢定 中高 級初 試（含）之上      [ citation :2 ]    托福網路測驗(TOEFL iBT)72分以上是申請進階英文免修的一個條件，但這並不是唯一的選擇，還有其他相關資訊需要考慮。
# 5 觸地 try 可得 5 分。根據橄欖球規則，當一名選手持有著足球並且在對方的進攻區域內將其踢在地上時，就會被判定為一個成功完成了 Try 的動作，這樣就可以獲得五分。  [citation:1][citation：2]
# 6 根據[webpage 1 begin]卑南族-维基百科，自由的... [citation:2][citaion：3]  答：  根据《維客》中的資料，我們可以知道 區祖先發源自ruvuwa'an。
# 7 根據搜尋結果，熊仔的父母都是臺灣大學教授。然而，並沒有明確提到他的碩士指導教師是誰。  但在[webpage 0]中，有一段描述說："祖 grandfather 熊智銳來自河南省，他曾任小學校長，并於1959年寫下知名兒歌及童詩〈大頭 大 头， 下雨不愁 〉。201 年他写了全台灣最高齡取得博士學位的紀錄。他5個孩子皆獲得博士学 位，其妻子王廷蘭曾获得「台湾生最多 博 士 的媽 媳」头衔，他也是家族中第11个有 PhD 背景的人。"  因此，我們可以推測熊仔可能是從他的祖父那裡學習到音樂創作的基礎知識。  但如果你想知道的是他碩士指導教授，那麼我無法提供相關資訊，因為搜尋結果並沒有提及這一點。
# 8 根據搜尋結果，法拉第（Michael Faraday）是發現電磁感應定律的人，他的實驗證明了當一個導線通過變化中的靜止或移動之間相互作用時，就會產生一種新的物理效能，即所謂「動物电」。這個研究結果奠定的基礎，對於電磁學和後續相關領域的發展具有重要意義。[citation:1]  法拉第在他的實驗中發現了當一個導線通過變化中的靜止或移動之間相互作用時，就會產生一種新的物理效能，即所謂「動物电」。這個研究結果奠定的基礎，對於電磁學和後續相關領域的發展具有重要意義。[citation:1]  法拉第還提出了力場理論，這是科學院中最為關鍵的一項概念之一。他也發明了「电解定律」，並創造了一系列與之相應電化學術語。  在後來的研究工作當中的，馬克斯威爾（James Clerk Maxwell）總結法拉第等人的成果，並建立起完整且精確地描述磁場和 電流間關係的一套理論框架。這個新發展奠定了電力工業以及相關領域在未來的基礎。  因此，根據搜尋結果，我們可以得出結论：法拉第是發現並提出的重要物理效能「動物电」，他對於科學院和後續研究工作具有深遠影響。
# 9 根據國立臺灣史前文化博物館的資訊，該建築位於台東市，並且有提到「1980年7月，因台灣鐵路管理局要興建南迴線卑 南車站（今臺 東 車 站），無意中發掘出藏 有大量文物 的 卞 曲 文 化 遺址。」[citation:1]因此，我們可以推斷距離國立臺灣史前文化博物館最近的台鐵车站在於該遺跡附近。  根據維基百科上的資訊，卑南車站（今臺東 車 站）位於 台 東 市，是一座重要的地標。[citation:0]因此，我們可以確定距離國立臺灣史前文化博物館最近的台鐵车站在於該遺跡附近，即是 臺东 车 场。  總結：答案為「Taipei車站」
# 10 根據搜尋結果，我們可以看到有兩個相關的網頁：  [webpage 0 begin]Whatis20+30=?-QuoraSomethingwentwrong.Waitamomentandtryagain.Try againPleaseenableJavascript andrefreshthepagetocontinue... [citation:1]   這一段內容似乎出現了錯誤，無法直接回答問題。  另一篇網頁是：  [webpage 2 begin]Flexianswers-Calculate20%of30.|CK-12FoundationAllSubjectsCBSEMathPercentageQuestionCalculate ...   雖然題目不是 "What is the result of adding two numbers?",但我們可以看到有關計算的內容。然而，這一段主要是針對百分比問題。  根據搜尋結果，我們無法直接找到答案。但是我建議你試著重新輸入或使用不同的搜索詞來查找相關資訊，或嘗试在Quora上再次尸检问题，可能會有更好的结果。
# 14 依據國立臺灣大學學則，停修有更嚴格的限制。根 據 [webpage 0] 的說明，每個 學期申請 停 修 科 目 以2科為限，只 限 於選擇課，但惟停止後之總学分數不得少於當時應繼續最低學 分 數。  因此，依據國立臺灣大學的規定，在沒有学生报告書的情況下，每個 學期至多停修 2 門 課程。
# 15 根據搜尋結果，DeepSeek公司的母 company 是幻方量化。[citation:0]
# 16 根據搜尋結果，2024年NBA總冠軍隊伍是波士頓塞爾提克（Boston Celtics）[citation:1]。他們在系列賽中以 3-0 的優勢擊敗達拉斯獨行俠 (Dallas Mavericks)，奪得了第18座 NBA 總決赛錦標 [ citation :2 ]。  另外，根據NBA獎項及榮譬列表的搜尋結果，我們可以看到總冠軍是由沃爾特·A.布朗（Walter A.Brown）杯頒發，而在1984年，這個名為拉里-奧伯萊恩 (Larry O'Brien) 的人被提到了 [ citation :3 ]。  最後，根據「盘点NBA各种奖项的名称和原型人物」的搜尋結果，我們可以看到總冠軍獎杯是以 Nba 总裁 拉里的名字命名，並在 1984 年正式使用。事實上，在1977年，這個名稱就已經開始出現，但當時它被稱為沃爾特-A-布朗奖 [ citation :5 ]。  綜合來說，2023年的NBA總冠軍隊伍是波士頓塞尔提克（Boston Celtics）。
# 17 碳氫化合物中，當有兩個或以上的原子之間形成三鍵時，這類型的情況被稱為炔烃。根據維基百科上的描述：  「若不考虑双键及三个共价连接同时出现的情况，以及二、三、四等多个碳-氢化合物中有两个或以上的原子之間形成三鍵時，這類型的情況被稱為炔烃。[19]」 [citation:1]  因此，當一個分子的某些部分具有三个共价连接（即是说，有兩個碳-氫键和一个C≡H或两个 C-H 键）时，它就可以称为一种有机化合物中的炔烃。
# 18 根據搜尋結果，艾倫·圖靈（Alan Turing）被譽為「計算機科學之父」，提出了图灵机概念，为現代计算理論奠定基礎。[citation:0] 他是英国电脑科学家、数学学者和逻辑哲士，也是一位长跑运动员。他在二次世界大战期间，参与破解德国海军密码的工作，并设计了一些加速打败Enigma机器技术。  图灵提出的著名概念包括：  1. 图靈機（Turing Machine）：一种理论计算模型，为现代計算理論奠定了基礎。 2..lambda演算：一个用于表达函数和程序的数学系统，具有同样的价值与圖林machine，但比之更简单、优雅实用。  图灵还提出了著名的问题「机器会思考吗？」（Can Machines Think?），并提出了一种测试方法，即现在被称为“Turing Test”的实验。[citation:0]
# 19 根據搜尋結果，臺灣玄天上帝信仰的進香中心位於南投縣名間鄉松山村。

# %%
with open('./private.txt', 'r') as input_f:
    questions = input_f.readlines()
    for id, question in enumerate(questions, 31):
        # if Path(f"./{STUDENT_ID}_{id}.txt").exists():
        #     continue
        answer = await pipeline(question)
        answer = answer.replace('\n',' ')
        print(id, answer)
        with open(f'./{STUDENT_ID}_{id}.txt', 'a') as output_f:
            print(answer, file=output_f)

# %%
# Combine the results into one file.
with open(f'./{STUDENT_ID}.txt', 'w') as output_f:
    for id in range(1,91):
        with open(f'./{STUDENT_ID}_{id}.txt', 'r') as input_f:
            answer = input_f.readline().strip()
            print(answer, file=output_f)
